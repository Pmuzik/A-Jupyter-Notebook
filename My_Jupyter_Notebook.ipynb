# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Patrick Musich**
# Data Collection Associate

# %% [markdown]
# *I'm interested in data science mostly because I dabbled in data visualization at another job and I found it very enjoyable. I actually discovered data science by accident while studying Python for completely different reasons. The more I learn about it, the more interesting it is because I'm discovering that I can apply data science ideas and techniques to a wide variety of subjects that interest me.*

# %% [markdown]
# ### The following code prints the result of 2 + 2.

# %%
print(2+2)
# Out:
# 4

# %% [markdown]
# - one
# - two
# - three
#
# 1. one
# 2. two
# 3. three
#
# ---
# ---
# ---
#
# |category 1|category 2|category 3|
# |---------|-----------|---------|
# |row1|a|b|
# |row2|a|b|
# |row3|a|b|
#
# https://www.ibm.com/,
# https://github.com/,
# https://google.com/
#
# ![2646-1-hunde-hintergrundbilder-hd-1993104315.jpg](attachment:2646-1-hunde-hintergrundbilder-hd-1993104315.jpg)
#
#
# `#This is code
# name = input('Hello, what is your name?')
# print('Nice to meet you '+ name +'!')`
#
# `This is another example of code/syntax highlighting`
#
# `and this makes *three*`
#
# >This is a block quote.
# Hello.
#
# >Here is another block quote.
#
# >And here is another one for good luck.
#
# ~~strike one~~!
#
# ~~strike two~~!
#
# ~~strike three~~!
# I'm out. The other two images are below. They would not render in the same cell as the first one for some reason.

# %% [markdown]
# ![th-1866433326.jpg](attachment:th-1866433326.jpg)

# %% [markdown]
# ![b0Q_qShh_400x400.jpg](attachment:b0Q_qShh_400x400.jpg)
